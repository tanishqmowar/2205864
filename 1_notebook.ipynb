# %% [markdown]
# <a href="https://colab.research.google.com/github/tanishqmowar/2205864/blob/main/1_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Exercise 2: Create markdown cell with title of the notebook

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# # Exercise 3 - Create a markdown cell for an introduction

# %% [markdown]
# #### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# # Exercise 4 - Create a markdown cell to list data science languages

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# # Exercise 5 - Create a markdown cell to list data science libraries

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow

# %% [markdown]
# # Exercise 6 - Create a markdown cell with a table of Data Science tools

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | RStudio            |
# | VS Code            |

# %% [markdown]
# # Exercise 7 - Create a markdown cell introducing arithmetic expression examples

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# # Exercise 8 - Create a code cell to multiply and add numbers

# %%
# This is a simple arithmetic expression to multiply then add integers
(3 * 4) + 5
# Out:
# 17

# %% [markdown]
# # Exercise 9 - Create a code cell to convert minutes to hours

# %%
# This will convert 200 minutes to hours by dividing by 60
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# # Exercise 10 - Insert a markdown cell to list Objectives

# %% [markdown]
# **Objectives:**
#
# - List popular languages for Data Science
# - Identify commonly used libraries in Data Science
# - Create tables to organize Data Science tools
# - Perform basic arithmetic operations in Python
# - Convert units using Python

# %% [markdown]
# # Exercise 11 - Create a markdown cell to indicate the Author's name

# %% [markdown]
# ## Author
# Tanishq Mowar
